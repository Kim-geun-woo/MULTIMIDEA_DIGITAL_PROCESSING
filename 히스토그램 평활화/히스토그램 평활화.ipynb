# %%
import cv2
import numpy as np

src = np. array([[0,0,0,0],
                 [1,1,1,1],
                 [200,200,200,200],
                 [250,250,250,250]], dtype = np.uint8)

dst = cv2.equalizeHist(src)
print(dst)
# Out:
# [[  0   0   0   0]
#  [ 85  85  85  85]
#  [170 170 170 170]
#  [255 255 255 255]]

# %% [markdown]
# # 새 섹션

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import cv2
from google.colab.patches import cv2_imshow
import sys
import numpy as np

src=cv2.imread('/content/drive/MyDrive/Colab Notebooks/DOG.bmp')

if src is None:
 print ('Image load failed')
 sys.exit()

dst=cv2.bilateralFilter (src,-1,10,5)

cv2_imshow(src)
cv2_imshow(dst)
cv2.waitKey()

cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=123x146 at 0x7F44AA3F1A30>
# <PIL.Image.Image image mode=RGB size=123x146 at 0x7F44A94EDFD0>

# %%
import cv2
import matplotlib.pyplot as plt

hist=cv2.calcHist([dst],[0],None,[256],[0,256])
plt.plot(hist)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/다운로드.jpg')

channels=cv2.split(img)
colors =['b', 'g', 'r']
for ch, color in zip(channels, colors):
  hist=cv2.calcHist([ch],[0],None,[256],[0,256])
  plt.plot(hist, color=color)
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
from google.colab.patches import cv2_imshow
import sys
import numpy as np
import os
import matplotlib.pyplot as plt

path = '/content/drive/MyDrive/Colab Notebooks/DOG.bmp'

# 입력 받은 이미지를 불러옵니다.
src = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
# 불러온 이미지에 histogram eqalization을 적용합니다.
dst = cv2.equalizeHist(src)
srcHist = cv2.calcHist(images = [src],
                       channels = [0],
                       mask = None,
                       histSize = [256],
                       ranges = [0, 256])

dstHist = cv2.calcHist(images = [dst],
                       channels = [0],
                       mask = None,
                       histSize = [256],
                       ranges = [0,256])

cv2_imshow(src)
cv2_imshow(dst)

plt.plot(srcHist, color = 'b', label = 'src hist')
plt.plot(dstHist, color = 'r', label = 'dst hist')
plt.legend(loc='best')
plt.show()

cv2.waitKey()

cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=123x146 at 0x7F449DA2FFD0>
# <PIL.Image.Image image mode=L size=123x146 at 0x7F449DA30FA0>

# %%
import cv2
import numpy as np

src = np. array([[3, 2, 2, 2, 2, 3, 3, 4],
                 [3, 2, 2, 2, 3, 4, 3, 3],
                 [4, 3, 3, 4, 4, 4, 3, 3],
                 [5, 4, 4, 4, 5, 4, 3, 3],
                 [5, 4, 3, 4, 5, 4, 3, 2],
                 [6, 5, 4, 4, 5, 4, 3, 2],
                 [6, 6, 5, 5, 4, 3, 2, 2],
                 [6, 5, 4, 5, 4, 3, 2, 2]], dtype = np.uint8)

dst = cv2.equalizeHist(src)
print(dst)
# Out:
# [[ 90   0   0   0   0  90  90 185]
#  [ 90   0   0   0  90 185  90  90]
#  [185  90  90 185 185 185  90  90]
#  [235 185 185 185 235 185  90  90]
#  [235 185  90 185 235 185  90   0]
#  [255 235 185 185 235 185  90   0]
#  [255 255 235 235 185  90   0   0]
#  [255 235 185 235 185  90   0   0]]

# %% [markdown]
# # 새 섹션
